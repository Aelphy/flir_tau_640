# %%
# %load_ext autoreload

# %autoreload 2

# %%
import cv2
import time
import crc16
import ctypes
import serial
import struct
import matplotlib.pyplot as plt
import numpy as np


from flir_driver import FlirDriver

# %matplotlib inline

# %%
def plot_snapshot(s):
    plt.figure(figsize=(10, 8))
    plt.imshow((s))
    plt.colorbar()
    plt.show()

# %%
d = FlirDriver("/dev/tty.SLAB_USBtoUART", 921600, False)

# %%
d.erase_snapshots()

# %%
d.capture_frame()
# Out:
# ('CAM_OK', b'\x08\x00')

# %%
snapshot = d.get_snapshot(0)

# %%
plot_snapshot(snapshot.T)
